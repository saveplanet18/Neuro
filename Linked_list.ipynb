# %%
class S_creation_node(object):

    def __init__(self,elements):
        self.elements = elements
        self.next = None

class S_Linked_List(object):

    def __init__(self):
        self.head = None

    def Insertion_at_Start(self,ele):
        ptr = S_creation_node(ele)
        if(self.head == None):
            self.head = ptr
            return
        else:
            ptr.next = self.head
            self.head = ptr
    
    def Insertion_at_Specific(self,pos,ele):
        ptr = S_creation_node(ele)
        if(pos < 1):
            print("should be greater than >= 1")
        elif(pos == 1 and self.head != None):
            ptr.next = self.head
            self.head = ptr
            return
        else:
            temp = self.head
            for i in range(pos-1):
                if(temp.next != None):
                    temp = temp.next
            if(temp != None):
                ptr.next = temp.next
                temp.next = ptr

    def Insertion_at_End(self,ele):
        ptr = S_creation_node(ele)
        if(self.head == None):
            ptr.next = self.head
            self.head = ptr
        else:
            temp = self.head
            while(temp.next != None):
                temp = temp.next
            temp.next = ptr
    
    def Deletion_at_Start(self):
        if(self.head == None):
            self.head = None
        else:
            temp = self.head
            self.head = self.head.next
            temp = None

    def Deletion_at_Specific(self,pos):
        if(pos < 1):
            print("should be greater than >= 1")
        elif(pos == 1 and self.head != None):
            mid_node = self.head
            self.head = self.head.next
            mid_node = None
        else:
            temp = self.head
            for i in range(pos-1):
                if(temp.next.next != None):
                    temp = temp.next
            if(temp != None and temp.next != None):
                mid_node = temp.next
                temp.next = temp.next.next
                mid_node = None
        
    def Deletion_at_End(self):
        if(self.head == None):
            self.head = None
        else:
            temp = self.head
            while(temp.next.next != None):
                temp = temp.next
            end_Node = temp.next
            temp.next = temp.next.next
            end_Node = None

    def DeleteallNode(self):
        while(self.head != None):
            temp = self.head
            self.head = self.head.next
            temp = None
    
    def CountNode(self):
        temp = self.head
        i = 0
        while (temp != None):
            i += 1
            temp = temp.next
        return i
    
    def search(self,key):
        temp = self.head
        found = 0
        i = 0
        if(temp != None):
            while(temp != None):
                i+=1
                if(temp.elements == key):
                    found+=1
                    break
                temp = temp.next
            if(found == 1):
                print(key,'key is found in the list',i)
            else:
                print(key,'key is not found')
        else:
            print("list is empty")

    def showlst(self):
        temp = self.head
        while(temp != None):
            print(temp.elements)
            temp = temp.next

# %%
sll = S_Linked_List()
sll.Insertion_at_Start(36)
sll.Insertion_at_Start(108)
sll.Insertion_at_Start(102)
sll.Insertion_at_Specific(2,104)
sll.Insertion_at_Specific(4,45)
sll.Insertion_at_Specific(3,109)
sll.Insertion_at_End(89)
sll.Insertion_at_End(358)
sll.Insertion_at_End(1008)
sll.showlst()
print("******")
# sll.Deletion_at_Start()
# sll.Deletion_at_Start()
# sll.Deletion_at_Specific(2)
# sll.Deletion_at_Specific(4)
# sll.Deletion_at_Specific(3)
# sll.Deletion_at_End()
# sll.Deletion_at_End()
# sll.Deletion_at_End()
# sll.Deletion_at_Specific(1)
# sll.DeleteallNode()
print(sll.CountNode())
sll.search(108)
sll.search(8888)
sll.showlst()
# Out:
# 102
# 108
# 104
# 109
# 36
# 45
# 89
# 358
# 1008
# ******
# 9
# 108 key is found in the list 2
# 8888 key is not found
# 102
# 108
# 104
# 109
# 36
# 45
# 89
# 358
# 1008

# %%
class D_Creation_Node(object):

    def __init__(self,elements):
        self.elements = elements
        self.next = None
        self.prev = None

class D_Linked_List(object):

    def __init__(self):
        self.head = None

    def Insertion_at_Start(self,ele):
        ptr = D_Creation_Node(ele)
        if(self.head == None):
            self.head = ptr
            ptr.prev = self.head
            return
        else:
            ptr.next = self.head
            self.head = ptr
            ptr.prev = self.head

    def Insertion_at_Specific(self,pos,ele):
        ptr = D_Creation_Node(ele)
        if(pos < 1):
            print("position should be >= 1")
        elif (pos == 1 and self.head != None):
            ptr.next = self.head
            self.head = ptr
            ptr.prev = self.head
            return
        else:
            temp = self.head
            for i in range(pos-1):
                if(temp.next != None):
                    temp = temp.next
            if(temp != None):
                ptr.next = temp.next
                temp.next = ptr
                ptr.prev = self.head

    def Insertion_at_End(self,ele):
        ptr = D_Creation_Node(ele)
        if(self.head == None):
            ptr.next = self.head
            self.head = ptr
            ptr.prev = self.head
            return
        else:
            temp = self.head
            while(temp.next != None):
                temp = temp.next
            temp.next = ptr
            ptr.prev = self.head
               
    def Deletion_at_Start(self):
        if(self.head == None):
            self.head = None
        else:
            temp = self.head
            self.head = self.head.next
            temp.prev = None

    def Deletion_at_Specific(self,pos):
        if(pos < 1):
            print("position should be >= 1")
        elif(pos == 1 and self.head != None):
            mid_node = self.head
            self.head = self.head.next
            mid_node = None
        else:
            temp = self.head
            for i in range(pos-1):
                if(temp.next.next != None):
                    temp = temp.next
            if(temp != None and temp.next != None):
                mid_node = temp.next
                temp.next = temp.next.next
                temp.prev = None

    def Deletion_at_End(self):
        if(self.head == None):
            end_node = self.head
            self.head = self.head.next
            end_node = None
        else:
            temp = self.head
            while(temp.next.next != None):
                temp = temp.next
            end_node = temp.next
            temp.next = temp.next.next
            temp.prev = None

    def CountNode(self):
        temp = self.head
        count = 0
        while(temp != None):
            count+=1
            temp = temp.next
        return count 

    def SerachNode(self,key):
        temp = self.head
        found = 0
        i = 0
        if(temp != None):
            while(temp != None):
                i+=1
                if(temp.elements == key):
                    found+=1
                    break
                temp = temp.next
            if(found == 1):
                print(key,"element is found ",i)
            else:
                print(key,'key is not fund ')
        else:
            print("list is empty")
                  
    def showlst(self):
        temp = self.head
        while(temp != None):
            print(temp.elements)
            temp = temp.next

# %%
dll = D_Linked_List()
dll.Insertion_at_Start(36)
dll.Insertion_at_Start(45)
dll.Insertion_at_Start(108)
dll.Insertion_at_Specific(2,109)
dll.Insertion_at_Specific(1,90)
dll.Insertion_at_Specific(3,89)
dll.Insertion_at_End(900)
dll.Insertion_at_End(32)
dll.Insertion_at_End(64)
dll.showlst()
print("******")
print(dll.CountNode())
dll.SerachNode(108)
dll.SerachNode(900)
dll.Deletion_at_Start()
dll.Deletion_at_Start()
dll.Deletion_at_Specific(2)
dll.Deletion_at_Specific(3)
dll.Deletion_at_Specific(1)
dll.Deletion_at_End()
dll.Deletion_at_End()
dll.Deletion_at_End()
dll.showlst()
# Out:
# 90
# 108
# 45
# 89
# 109
# 36
# 900
# 32
# 64
# ******
# 9
# 108 element is found  2
# 900 element is found  7
# 89

# %%
class C_creation_Node(object):

    def __init__(self,elements):
        self.elements = elements
        self.next = None


class C_Linked_List(object):

    def __init__(self):
        self.head = None

    def Insertion_at_start(self,ele):
        ptr = C_creation_Node(ele)
        if(self.head == None):
            self.head = ptr
            ptr.next = self.head
            return

        else:
            temp = self.head
            while(temp.next != self.head):
                temp = temp.next
            temp.next = ptr
            ptr.next = self.head
            self.head = ptr

    def Insertion_at_specific(self,pos,ele):
        ptr = C_creation_Node(ele)
        if(pos < 1):
            print("position should be >= 1")
        elif(pos == 1 and self.head == None):
            ptr.next = self.head
            self.head = ptr
            return

        else:
            temp = self.head
            for i in range(pos-1):
                if(temp.next != self.head):
                    temp = temp.next
            if(temp != None):
                ptr.next = temp.next
                temp.next = ptr
    
    def Insertion_at_End(self,ele):
        ptr = C_creation_Node(ele)
        if(self.head == None):
            self.head = ptr
            ptr.next  = self.head
            return
        else:
            temp = self.head
            while(temp.next != self.head):
                temp = temp.next
            temp.next = ptr
            ptr.next = self.head

    def Deletion_at_First(self):
        if(self.head != None):
            if(self.head.next == self.head):
                self.head = None
            else:
                temp = self.head
                first_node = self.head
                while(temp.next != self.head):
                    temp = temp.next
                self.head = self.head.next
                temp.next = self.head
                first_node = None
    
    def Deletion_at_specific(self,pos):
        if(pos < 1):
            print("position is >= 1")
        elif(pos == 1 and self.head.next == self.head):
            self.head = None
        else:
            temp = self.head
            while(temp.next != self.head):
                temp = temp.next
            if(temp != None):
                mid_node = temp.next
                self.head = self.head.next
                temp.next = self.head
                mid_node = None
    
    def Deletion_at_End(self):
        if(self.head == None):
            self.head = None
        else:
            temp = self.head
            while(temp.next.next != self.head):
                temp = temp.next
            end_node = temp.next
            temp.next = self.head
            end_node = None
            
    def Count_Node(self):
        count = 0
        temp = self.head
        if(temp != None):
            count+=1
            temp = temp.next
        while(temp.next != self.head):
            count+=1
            temp = temp.next
        return count

    def Search_Node(self,search):
        found = 0
        i = 0
        temp = self.head
        if(temp != None):
            while(temp != None):
                i+=1
                if(temp.elements == search):
                    found+=1
                    break
                temp = temp.next
                if(temp == self.head):
                    break
            if(found == 1):
                print(search,"element is found is ",i)
            else:
                print(search,'element is not found')
        else:
            print("list is empty")    


    def showlst(self):
        temp = self.head
        while(temp != None):
            print(temp.elements)
            temp = temp.next
            if(temp == self.head):
                break

# %%
cll = C_Linked_List()
cll.Insertion_at_start(36)
cll.Insertion_at_start(45)
cll.Insertion_at_start(108)
cll.Insertion_at_specific(1,89)
cll.Insertion_at_specific(1,90)
cll.Insertion_at_specific(1,10)
cll.Insertion_at_End(300)
cll.Insertion_at_End(600)
cll.Insertion_at_End(900)
cll.Search_Node(900)
cll.showlst()
print(cll.Count_Node())
print("******")
cll.Deletion_at_First()
cll.Deletion_at_First()
cll.Deletion_at_specific(2)
cll.Deletion_at_specific(1)
cll.Deletion_at_specific(1)
cll.Deletion_at_End()
cll.Deletion_at_End()
cll.showlst()
# Out:
# 900 element is found is  9
# 108
# 10
# 90
# 89
# 45
# 36
# 300
# 600
# 900
# 8
# ******
# 36
# 300

# %%
class CD_Creation_Node(object):

    def __init__(self,elements):
        self.elements = elements
        self.next = None
        self.prev = None

class CD_Linked_List(object):

    def __init__(self):
        self.head = None
    
    def Insertion_at_start(self,ele):
        ptr = CD_Creation_Node(ele)
        if(self.head == None):
            self.head = ptr
            ptr.next = self.head
            ptr.prev = self.head
            return
        else:
            temp = self.head
            while(temp.next != self.head):
                temp = temp.next
            temp.next = ptr
            ptr.next = self.head
            ptr.prev = self.head
            self.head = ptr
    
    def Insertion_at_specific(self,pos,ele):
        ptr = CD_Creation_Node(ele)
        if(pos < 1):
            print("position is >= 1")
        elif(pos == 1 and self.head == None):
            self.head = ptr
            ptr.next = self.head
            ptr.prev = self.head
            return
        else:
            temp = self.head
            for i in range(pos-1):
                if(temp.next != self.head):
                    temp = temp.next
            if(temp != None):
                ptr.next = temp.next
                temp.next = ptr
                ptr.prev = self.head

    def Insertion_at_End(self,ele):
        ptr = CD_Creation_Node(ele)
        if(self.head == None):
            self.head = ptr
            ptr.next = self.head
            ptr.prev = self.head
            return
        else:
            temp = self.head
            while(temp.next != self.head):
                temp = temp.next
            temp.next = ptr
            ptr.next = self.head
            ptr.prev = temp

    def Deletion_at_start(self):
        if(self.head.next == self.head):
            self.head = None
        else:
            temp = self.head
            while(temp.next != self.head):
                temp = temp.next
            first = self.head
            self.head = self.head.next
            self.head.prev = temp
            temp.next = self.head
            first = None 

    def Deletion_at_specific(self,pos):
        if(pos < 1):
            print("position is >= 1")
        elif(pos == 1 and self.head == None):
            self.head = None
            self.head.next = None
        else:
            temp = self.head
            for i in range(pos-1):
                if(temp.next != self.head):
                    temp = temp.next
            if(temp != None):
                mid_node = temp.next
                temp.next = temp.next.next
                temp.next.prev = temp
                mid_node = None

    def Deletion_at_end(self):
        if(self.head == None):
            self.head = None
        else:
            temp = self.head
            while(temp.next.next != self.head):
                temp = temp.next
            end_node = temp.next
            temp.next = self.head
            self.head.prev = temp
            end_node = None
            
    def showlist(self):
        temp = self.head
        while(temp != None):
            print(temp.elements)
            temp = temp.next
            if(temp == self.head):
                break

# %%
cdll = CD_Linked_List()
cdll.Insertion_at_start(36)
cdll.Insertion_at_start(45)
cdll.Insertion_at_start(108)
cdll.Insertion_at_specific(1,89)
cdll.Insertion_at_specific(1,90)
cdll.Insertion_at_specific(2,100)
cdll.Insertion_at_End(300)
cdll.Insertion_at_End(600)
cdll.Insertion_at_End(900)
cdll.showlist()
print("******")
cdll.Deletion_at_start()
cdll.Deletion_at_start()
cdll.Deletion_at_specific(1)
cdll.Deletion_at_specific(1)
cdll.Deletion_at_specific(2)
cdll.Deletion_at_end()
cdll.Deletion_at_end()
cdll.showlist()
# Out:
# 108
# 90
# 100
# 89
# 45
# 36
# 300
# 600
# 900
# ******
# 100
# 36
