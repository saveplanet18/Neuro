# %%
class Singly_Creation_Node(object):

    def __init__(self,elements):
        self.elements = elements
        self.next = None


class Singly_Linked_List(object):

    def __init__(self):
        self.Head = None


    def Insertion_at_front(self,ele):
        ptr = Singly_Creation_Node(ele)
        if (self.Head == None):
            self.Head = ptr
            return
        else:
            ptr.next = self.Head
            self.Head = ptr

    def Insertion_at_specific(self,pos,ele):
        ptr = Singly_Creation_Node(ele)
        if (pos < 1) :
            print("position is greater than >= 1")
        elif (pos == 1 and self.Head == None):
            self.Head = ptr
            ptr.next = self.Head
            return
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.next != None):
                    temp = temp.next
            if (temp != None):
                ptr.next = temp.next
                temp.next = ptr
                
    def Insertion_at_rear(self,ele):
        ptr = Singly_Creation_Node(ele)
        if (self.Head == None):
            self.Head = ptr
            ptr.next = self.Head
            return
        else:
            temp = self.Head
            while (temp.next != None):
                temp = temp.next
            temp.next = ptr

    def Search_Node(self,search):
        temp = self.Head
        found = 0
        i = 0
        if (temp != None):
            while (temp != None):
                i +=1
                if (temp.elements == search):
                    found +=1
                    break
                temp = temp.next
            if (found == 1):
                print(found,'elements is found ',i)
            else:
                print(found , "element is not found" ,i )
                
    def Count_Node(self):
        count = 0
        temp = self.Head
        while (temp != None):
            count +=1
            temp = temp.next
        return count

    def Deletion_at_front(self):
        if (self.Head == None):
            self.Head = None
        else:
            temp = self.Head
            self.Head = self.Head.next
            temp = None

    def Deletion_at_specific(self,pos):
        if (pos < 1):
            print("position is greater than >= 1")
        elif (pos == 1 and self.Head == None):
            self.Head = None
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.next != None):
                    temp = temp.next
            if (temp != None):
                Mid_node = temp.next
                temp.next = temp.next.next
                Mid_node = None

    def Deletion_at_rear(self):
        if (self.Head == None):
            self.Head = None
        else:
            temp = self.Head
            while (temp.next.next != None):
                temp = temp.next
            end_node = temp.next
            temp.next = temp.next.next
            end_node = None

    def Traverse(self):
        temp = self.Head
        while (temp != None):
            print(temp.elements)
            temp = temp.next

# %%
si = Singly_Linked_List()
si.Insertion_at_front(18)
si.Insertion_at_front(108)
si.Insertion_at_specific(1,63)
si.Insertion_at_specific(1,45)
si.Insertion_at_rear(54)
si.Insertion_at_rear(100)
si.Search_Node(54)
print(si.Count_Node())
si.Deletion_at_front()
si.Deletion_at_front()
si.Deletion_at_specific(1)
si.Deletion_at_specific(1)
si.Deletion_at_rear()
# si.Deletion_at_rear()
si.Deletion_at_front()
si.Traverse()
# Out:
# 1 elements is found  5
# 6

# %%
class Circular_Creation_Node(object):

    def __init__(self,elements):
        self.elements = elements
        self.next = None

class Circular_Linked_List(object):

    def __init__(self):
        self.Head = None

    def Insertion_at_front(self,ele):
        ptr = Circular_Creation_Node(ele)
        if (self.Head == None):
            self.Head = ptr
            ptr.next = self.Head
            return
        else:
            temp = self.Head
            while (temp.next != self.Head):
                temp = temp.next
            temp.next = ptr
            ptr.next = self.Head
            self.Head = ptr

    def Insertion_at_specific(self,pos,ele):
        ptr = Circular_Creation_Node(ele)
        if (pos < 1):
            print("position is greater than >= 1")
        elif (pos == 1 and self.Head == None):
            self.Head = ptr
            ptr.next = self.Head
            self.Head = ptr
            return
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.next != self.Head):
                    temp = temp.next
            if (temp != None):
                ptr.next = temp.next
                temp.next = ptr

    def Insertion_at_rear(self,ele):
        ptr = Singly_Creation_Node(ele)
        if (self.Head == None):
            self.Head = ptr
            ptr.next = self.Head
            self.Head = ptr
            return
        else:
            temp = self.Head
            while (temp.next != self.Head):
                temp = temp.next
            temp.next = ptr
            ptr.next = self.Head

    def Search_Node(self,Search):
        temp = self.Head
        found = 0
        i = 0
        if (temp != None):
            while (temp != None):
                i +=1
                if (temp.elements == Search):
                    found +=1
                    break
                temp = temp.next
            if (found == 1):
                print(found , "elements is found " ,i)
            else:
                print(found , "elements is not found ",i)
    
    def Count_Node(self):
        count = 0
        temp = self.Head
        while (temp.next != self.Head):
            temp = temp.next
            count+=1
        return count
    
    def Deletion_at_front(self):
        if (self.Head == None):
            self.Head = None
        else:
            temp = self.Head
            while (temp.next != self.Head):
                temp = temp.next
            first_node = temp.next
            self.Head = self.Head.next
            temp.next = self.Head
            first_node = None

    def Deletion_at_specific(self,pos):
        if (pos < 1 ):
            print("position is greater than >= 1")
        elif (pos == 1 and self.Head == None):
            first_node = self.Head
            self.Head = self.Head.next
            first_node = None
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.next != self.Head):
                    temp = temp.next
            if (temp != None):
                Mid_node = temp.next
                temp.next = temp.next.next

    def Deletion_at_rear(self):
        if (self.Head == None):
            self.Head = None
        else:
            temp = self.Head
            while (temp.next.next != self.Head):
                temp = temp.next
            end_node = temp.next
            temp.next = self.Head
            end_node = None
            
    def Traverse(self):
        temp = self.Head
        while (temp != None):
            print(temp.elements)
            temp = temp.next
            if (temp == self.Head):
                break

# %%
di = Circular_Linked_List()
di.Insertion_at_front(18)
di.Insertion_at_front(108)
di.Insertion_at_specific(1,23)
di.Insertion_at_specific(1,54)
di.Insertion_at_rear(100)
di.Insertion_at_rear(101)
di.Search_Node(23)
print(di.Count_Node())
di.Deletion_at_front()
di.Deletion_at_front()
di.Deletion_at_specific(1)
di.Deletion_at_specific(2)
di.Deletion_at_rear()
di.Traverse()
# Out:
# 1 elements is found  3
# 5
# 23

# %%
class Double_Creation_Node(object):

    def __init__(self,elements):
        self.elements = elements
        self.next = None
        self.prev = None

class Doubly_Linked_List(object):

    def __init__(self):
        self.Head = None

    def Insertion_at_front(self,ele):
        ptr = Double_Creation_Node(ele)
        if (self.Head == None):
            self.Head = ptr
            return
        else:
            ptr.next = self.Head
            self.Head = ptr
            ptr.prev = self.Head

    def Insertion_at_specific(self,pos,ele):
        ptr = Double_Creation_Node(ele)
        if (pos < 1 ):
            print("position is greater than >= 1")
        elif (pos == 1 and self.Head == None):
            ptr.next = self.Head
            self.Head = ptr
            ptr.prev = self.Head
            return
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.next != None):
                    temp = temp.next
            if (temp != None):
                ptr.next = temp.next
                temp.next = ptr
                ptr.prev = self.Head
                
    def Insertion_at_rear(self,ele):
        ptr = Double_Creation_Node(ele)
        if (self.Head == None):
            ptr.next = self.Head
            self.Head = ptr
            ptr.prev = self.Head
            return
        else:
            temp = self.Head
            while (temp.next != None):
                temp = temp.next
            temp.next = ptr
            ptr.prev = self.Head 

    def Search_Node(self,search):
        temp = self.Head
        found = 0
        i = 0
        if (temp != None):
            while (temp != None):
                i +=1
                if (temp.elements == search):
                    found +=1
                    break
                temp = temp.next
            if (found == 1):
                print(found , 'elment is found' ,i)
            else:
                print(found , "element is not found" ,i)

    def Count_Node(self):
        count = 0
        temp = self.Head
        while (temp != None):
            count +=1
            temp = temp.next
        return count 

    def Deletion_at_front(self):
        if (self.Head == None):
            self.Head = None
        else:
            temp = self.Head
            self.Head = self.Head.next
            temp.prev = None 

    def Deletion_at_specific(self,pos):
        if (pos < 1):
            print("position is greater than >= 1")
        elif (pos == 1 and self.Head == None):
            first_node = self.Head
            self.Head = self.Head.next
            first_node.prev = None
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.next != None):
                    temp = temp.next
            if (temp != None):
                mid_node = temp.next
                temp.next = temp.next.next
                mid_node.prev = None 

    def Deletion_at_rear(self):
        if (self.Head == None):
            first_node = self.Head
            self.Head = self.Head.next
            first_node = None
        else:
            temp = self.Head
            while (temp.next.next != None):
                temp = temp.next
            last_node = temp.next
            temp.next = temp.next.next
            last_node.prev = None  

    def Traverse(self):
        temp = self.Head
        while (temp != None):
            print(temp.elements)
            temp = temp.next

# %%
di = Doubly_Linked_List()
di.Insertion_at_front(18)
di.Insertion_at_front(36)
di.Insertion_at_specific(1,54)
di.Insertion_at_specific(2,65)
di.Insertion_at_rear(100)
di.Insertion_at_rear(101)
di.Search_Node(65)
print(di.Count_Node())
di.Deletion_at_front()
di.Deletion_at_front()
di.Deletion_at_specific(1)
# di.Deletion_at_specific(1)
di.Deletion_at_rear()
di.Deletion_at_rear()
di.Traverse()
# Out:
# 1 elment is found 3
# 6
# 65

# %%
class DC_Creation_Node(object):

    def __init__(self,elements):
        self.elements = elements
        self.next = None
        self.prev = None
        
class DC_Linked_List(object):

    def __init__(self):
        self.Head = None

    def Insertion_at_front(self,ele):
        ptr = DC_Creation_Node(ele)
        if (self.Head == None):
            self.Head = ptr
            ptr.next = self.Head
            ptr.prev = self.Head
            return
        else:
            temp = self.Head
            while (temp.next != self.Head):
                temp = temp.next
            temp.next = ptr
            ptr.next = self.Head
            self.Head = ptr
            ptr.prev = self.Head

    def Insertion_at_specific(self,pos,ele):
        ptr = DC_Creation_Node(ele)
        if (pos < 1):
            print("position is greater than >= 1")
        elif (pos == 1 and self.Head == None):
            self.Head = ptr
            ptr.next = self.Head
            ptr.prev = self.Head
            return
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.next != self.Head):
                    temp = temp.next
            if (temp != None):
                ptr.next = temp.next
                temp.next = ptr
                ptr.prev = self.Head

    def Insertion_at_rear(self,ele):
        ptr = DC_Creation_Node(ele)
        if (self.Head == None):
            self.Head = ptr
            ptr.next = self.Head
            ptr.prev = self.Head
            return
        else:
            temp = self.Head
            while (temp.next != self.Head):
                temp = temp.next
            temp.next = ptr
            ptr.next = self.Head
            self.Head.prev = ptr

    def Search_Node(self,search):
        temp = self.Head
        found = 0
        i = 0
        if (temp != None):
            while (temp != None):
                i +=1
                if (temp.elements == search):
                    found +=1
                    break
                temp = temp.next
            if (found == 1):
                print(found , "element is found ", i)
            else:
                print(found , "element is not found ", i)
                
    def count_node(self):
        temp = self.Head
        count = 0
        while (temp.next != self.Head):
            count =+1
            temp = temp.next
        return count

    def Deletion_at_front(self):
        if (self.Head == None):
            self.Head = None
        else:
            temp = self.Head
            while (temp.next != self.Head):
                temp = temp.next
            first_node = temp.next
            self.Head = self.Head.next
            temp.next = self.Head
            first_node.prev = None

    def Deletion_at_specific(self,pos):
        if (pos < 1):
            print("position is greater than >= 1")
        elif (pos == 1 and self.Head == None):
            first = self.Head
            self.Head = self.Head.next
            first.prev = None
            return
        else:
            temp = self.Head
            for i in range(pos-1):
                if (temp.next != self.Head):
                    temp = temp.next
            if (temp != None):
                mid_node = temp.next
                temp.next = temp.next.next
                mid_node.prev = None 
    def Deletion_at_rear(self):
        if (self.Head == None):
            first_node = self.Head
            self.Head = self.Head.next
            first_node.prev = self.Head
            first_node = None
        else:
            temp = self.Head
            while (temp.next.next != self.Head):
                temp = temp.next
            end_node = temp.next
            temp.next = self.Head
            end_node.prev = None      
        
    def Traveerse(self):
        temp = self.Head
        while (temp != None):
            print(temp.elements)
            temp = temp.next
            if (temp == self.Head):
                break

# %%
dc = DC_Linked_List()
dc.Insertion_at_front(18)
dc.Insertion_at_front(25)
dc.Insertion_at_specific(1,54)
dc.Insertion_at_specific(1,68)
dc.Insertion_at_rear(87)
dc.Insertion_at_rear(88)
dc.Search_Node(54)
print(dc.count_node())
dc.Deletion_at_front()
dc.Deletion_at_front()
dc.Deletion_at_specific(1)
dc.Deletion_at_rear()
dc.Deletion_at_rear()
dc.Deletion_at_front()
dc.Traveerse()
# Out:
# 1 element is found  3
# 1
# 54

# %%
class Normal_Queue(object):

    def __init__(self,elments):
        self.elements = elments
        self.Queue = [None] * elments
        self.front = -1
        self.rear = -1

    def Insertion_at_rear(self,ele):
        if (self.rear + 1) == self.elements-1:
            print("Queue is overflow")
        elif (self.front == -1 and self.rear == -1):
            self.front = 0
            self.rear = 0
        else:
            self.rear = (self.rear + 1)
        add = self.Queue[self.rear] = ele
        return add

    def Deletion_at_front(self):
        if (self.rear == -1 and self.rear == -1):
            print("Queue is emtpy")
        elif (self.front == self.rear):
            self.front = -1
            self.rear = -1
        else:
            remove = self.Queue[self.front]
            self.front = self.front + 1
            return
    
    def Traverse(self):
        if (self.rear == -1 and self.rear == -1):
            print("Queue is empty ")
        else:
            while (self.front != self.rear):
                print(self.Queue[self.front])
                self.front = (self.front +1 ) % self.elements
            print(self.Queue[self.rear])

# %%
nq = Normal_Queue(9)
nq.Insertion_at_rear(18)
nq.Insertion_at_rear(45)
nq.Insertion_at_rear(36)
nq.Deletion_at_front()
nq.Insertion_at_rear(108)
nq.Insertion_at_rear(69)
nq.Deletion_at_front()
nq.Deletion_at_front()
nq.Insertion_at_rear(81)
nq.Insertion_at_rear(63)
nq.Deletion_at_front()
nq.Deletion_at_front()
nq.Traverse()
# Out:
# 81
# 63

# %%
class new_creation_Node(object):
    def __init__(self,elements):
        self.elements = elements
        self.next = None

class new_Linked_List(object):
    def __init__(self):
        self.Head = None

    def Insertion_at_rear(self,ele):
        ptr = new_creation_Node(ele)
        if (self.Head == None):
            self.Head = ptr
            ptr.next = self.Head
            return
        else:
            temp = self.Head
            while (temp.next != self.Head):
                temp = temp.next
            temp.next = ptr
            ptr.next = self.Head
    
    def Deletion_at_front(self):
        if (self.Head == None):
            self.Head = None
        else:
            temp = self.Head
            while (temp.next != self.Head):
                temp = temp.next
            first_node = None
            self.Head = self.Head.next
            temp.next = self.Head
            first_node = None
    
    def Traverse(self):
        temp = self.Head
        while (temp != None):
            print(temp.elements)
            temp = temp.next
            if (temp == self.Head):
                break

# %%
nn = new_Linked_List()
nn.Insertion_at_rear(18)
nn.Insertion_at_rear(45)
nn.Deletion_at_front()
nn.Insertion_at_rear(63)
nn.Insertion_at_rear(54)
nn.Deletion_at_front()
nn.Deletion_at_front()
nn.Traverse()
# Out:
# 54

# %%
class sikk_creation_node(object):
    def __init__(self,elements):
        self.elements = elements
        self.next = None

class sikk_Linked_List(object):
    def __init__(self):
        self.Head = None

    def Insertion_at_rear(self,ele):
        ptr = sikk_creation_node(ele)
        if (self.Head == None):
            ptr.next = self.Head
            self.Head = ptr
            return
        else:
            temp = self.Head
            while (temp.next != None):
                temp = temp.next
            temp.next = ptr

    def Deletion_at_front(self):
        if (self.Head == None):
            self.Head = None
        else:
            temp = self.Head
            self.Head = self.Head.next
            temp = None
    
    def Traverse(self):
        temp = self.Head
        while (temp != None):
            print(temp.elements)
            temp = temp.next

# %%
kk = sikk_Linked_List()
kk.Insertion_at_rear(18)
kk.Insertion_at_rear(35)
kk.Insertion_at_rear(45)
kk.Deletion_at_front()
kk.Deletion_at_front()
kk.Traverse()
# Out:
# 45

# %%
class DDouble_Creation_Node(object):
    def __init__(self,elements):
        self.elements = elements
        self.next = None
        self.prev = None

class DDouble_Linked_List(object):
    def __init__(self):
        self.Head = None

    def Insertion_at_rear(self,ele):
        ptr = DDouble_Creation_Node(ele)
        if (self.Head == None):
            ptr.next = self.Head
            self.Head = ptr
            ptr.prev = self.Head
            return 
        else:
            temp = self.Head
            while (temp.next != None):
                temp = temp.next
            temp.next = ptr
            ptr.prev = self.Head
    
    def Deletion_at_rear(self):
        if (self.Head == None):
            first_Node  = self.Head
            self.Head = self.Head.next
            first_Node.prev = None
        else:
            temp = self.Head
            while (temp.next.next != None):
                temp = temp.next
            end_node = self.Head
            temp.next = temp.next.next
            end_node.prev = None
    
    def Traverse(self):
        temp = self.Head
        while (temp != None):
            print(temp.elements)
            temp = temp.next

# %%
malingray = DDouble_Linked_List()
malingray.Insertion_at_rear(18)
malingray.Insertion_at_rear(45)
malingray.Insertion_at_rear(89)
malingray.Insertion_at_rear(32)
malingray.Deletion_at_rear()
malingray.Deletion_at_rear()
malingray.Traverse()
# Out:
# 18
# 45

# %%
class DC_Node(object):

    def __init__(self,elements):
        self.elements = elements
        self.next = None
        self.prev = None

class DC_Node_Link(object):

    def __init__(self):
        self.Head = None

    def Insertion_at_rear(self,ele):
        ptr = DC_Node(ele)
        if (self.Head == None):
            self.Head = ptr
            ptr.next = self.Head
            ptr.prev = self.Head
            return
        else:
            temp = self.Head
            while (temp.next != self.Head):
                temp = temp.next
            temp.next = ptr
            ptr.prev = self.Head
    
    def Traverse(self):
        temp = self.Head
        while (temp != None):
            print(temp.elements)
            temp = temp.next
            if (temp == self.Head):
                break

# %%
dg = DC_Node_Link()
dg.Insertion_at_rear(18)
dg.Insertion_at_rear(45)
dg.Insertion_at_rear(81)
dg.Insertion_at_rear(24)
dg.Traverse()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6620/1031543756.py in <module>
#       2 dg.Insertion_at_rear(18)
#       3 dg.Insertion_at_rear(45)
# ----> 4 dg.Insertion_at_rear(81)
#       5 dg.Insertion_at_rear(24)
#       6 dg.Traverse()
#
# ~\AppData\Local\Temp/ipykernel_6620/3755704248.py in Insertion_at_rear(self, ele)
#      20         else:
#      21             temp = self.Head
# ---> 22             while (temp.next != self.Head):
#      23                 temp = temp.next
#      24             temp.next = ptr
#
# AttributeError: 'NoneType' object has no attribute 'next'
